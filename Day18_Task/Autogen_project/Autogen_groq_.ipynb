# %%
# Install AutoGen Studio and pyngrok
# !pip install -q autogenstudio pyngrok

# Verify the installation
# !autogenstudio version
# Out:
# AutoGen Studio  CLI version: 0.4.2.2

# %%
import os
import getpass

# 1. Set up Groq API Key
if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API Key: ")

# 2. Set up Ngrok Auth Token (Required to tunnel the AutoGen Studio UI)
NGROK_TOKEN = getpass.getpass("Enter your Ngrok Auth Token: ")
# !ngrok config add-authtoken {NGROK_TOKEN}
# Out:
# Enter your Ngrok Auth Token: ··········
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import multiprocessing
import time
from pyngrok import ngrok

def run_autogen_studio():
    # Launch AutoGen Studio on port 8081
    # !autogenstudio ui --port 8081 --host 0.0.0.0

# Start AutoGen Studio in a background process
process = multiprocessing.Process(target=run_autogen_studio)
process.start()

# Wait a moment for the server to spin up
time.sleep(5)

# Open the ngrok tunnel to port 8081
public_url = ngrok.connect(8081)
print("\n" + "="*60)
print(f"[SUCCESS] AutoGen Studio is running!")
print(f"Click the link below to open the UI:")
print(f"{public_url}")
print("="*60 + "\n")
# Out:
# ============================================================
# [SUCCESS] AutoGen Studio is running!
# Click the link below to open the UI:
# NgrokTunnel: "https://energetic-cardboard-smock.ngrok-free.dev" -> "http://localhost:8081"
# ============================================================

# %%
import os
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_ext.models.openai import OpenAIChatCompletionClient

async def run_team():
    groq_key = os.environ.get("GROQ_API_KEY", "")

    researcher_model = OpenAIChatCompletionClient(
        model="llama-3.1-8b-instant",
        base_url="https://api.groq.com/openai/v1",
        api_key=groq_key,
        model_info={
            "vision": False,
            "function_calling": True,
            "json_output": True,
            "structured_output": True,
            "family": "unknown"
        }
    )

    editor_model = OpenAIChatCompletionClient(
        model="llama-3.3-70b-versatile",
        base_url="https://api.groq.com/openai/v1",
        api_key=groq_key,
        model_info={
            "vision": False,
            "function_calling": True,
            "json_output": True,
            "structured_output": True,
            "family": "unknown"
        }
    )

    researcher = AssistantAgent(
        name="Researcher",
        model_client=researcher_model,
        system_message="You are an expert researcher. Provide a highly detailed summary using clear Markdown formatting."
    )

    editor = AssistantAgent(
        name="Editor",
        model_client=editor_model,
        system_message="You are a strict editor. Critique the researcher's work and optimize it for professional delivery."
    )

    team = RoundRobinGroupChat(
        participants=[researcher, editor],
        termination_condition=MaxMessageTermination(max_messages=4)
    )

    print("--- Starting Multi-Agent Session ---")
    async for message in team.run_stream(task="Explain why Groq LPUs provide higher throughput for LLMs than standard GPUs."):
        # Skip the final TaskResult object — only print agent messages
        if hasattr(message, "source"):
            print(f"\n\033[1m[{message.source}]\033[0m: {message.content}")
            print("-" * 40)

await run_team()
# Out:
# --- Starting Multi-Agent Session ---
#
# [user]: Explain why Groq LPUs provide higher throughput for LLMs than standard GPUs.
# ----------------------------------------
#
# [Researcher]: **Understanding Groq LPUs and their Advantages for Large Language Models (LLMs)**
# ================================================================================
#
# **Introduction**
# ---------------
#
# The rapid growth of Large Language Models (LLMs) has led to an increasing need for more powerful computing hardware that can efficiently process these complex neural networks. General-purpose Graphics Processing Units (GPUs) have become a staple in AI research, but recent advancements in custom-designed hardware have led to the development of Linear-Processing-Units (LPUs) as an alternative. This summary will delve into the architecture and benefits of Groq LPUs, specifically in relation to their ability to provide higher throughput for LLMs compared to standard GPUs.
#
# **Groq LPU Architecture**
# -------------------------
#
# Groq LPUs are custom-designed processors optimized for Linear Algebra and Neural Network computations. Their unique architectural features enable them to efficiently handle the matrix operations required for LLMs. Key differences between Groq LPUs and standard GPUs are:
#
# ### **Parallel Processing**
#
# Unlike traditional GPUs, which rely on a mix of serial and parallel processing, Groq LPUs employ a single Instruction Multiple Data (SIMD) execution paradigm for matrix operations. This streamlined architecture minimizes overhead and maximizes data throughput, making it ideal for complex neural network computations.
#
# ### **High-Density, On-Chip Fabric**
#
# Groq LPUs incorporate an efficient on-chip communication fabric, which enables rapid exchange of data between processing units. This eliminates the need for external memory access, reducing latency and improving performance.
#
# ### **Specialized Matrix-Vector Units (SMMU)**
#
# Groq LPUs are equipped with specialized Matrix-Vector Units (SMMUs), which are highly optimized for linear algebra operations. These units employ a unique instruction format that allows for efficient processing of sparse and dense matrices.
#
# **Benefits for Large Language Models (LLMs)**
# --------------------------------------------
#
# Groq LPUs' tailored architecture provides significant benefits for LLMs:
#
# ### **Improved Throughput**
#
# The combination of high-density on-chip fabric, SIMD execution, and SMMUs enables Groq LPUs to achieve higher matrix operation speeds, resulting in increased throughput for LLM computations.
#
# ### **Enhanced Power Efficiency**
#
# Groq LPUs are designed to minimize power consumption while maintaining performance. This is crucial for LLM training, which requires massive datasets and lengthy processing times.
#
# ### **Reduced Latency**
#
# Groq LPUs' streamlined architecture and on-chip fabric reduce latency for matrix operations, which is essential for real-time LLM applications.
#
# **Comparison with Standard GPUs**
# --------------------------------
#
# While standard GPUs excel at general-purpose computation, they fall short in comparison to Groq LPUs for LLMs:
#
# ### **GPU Bottleneck**
#
# GPUs rely heavily on traditional parallel computing architectures, which introduce bottlenecks during LLM computations.
#
# ### **Memory Bandwidth Limitations**
#
# GPUs' external memory access patterns can lead to limited memory bandwidth, negatively impacting performance.
#
# ### **Instruction-Level Overhead**
#
# GPUs incur additional overhead due to serial execution of certain instructions, which slows down LLM computations.
#
# **Conclusion**
# ----------
#
# Groq LPUs offer a superior architecture for Large Language Model computations, providing higher throughput, improved power efficiency, and reduced latency. By leveraging a custom-designed paradigm, optimized matrix-vector units, and a high-density on-chip fabric, Groq LPUs outperform standard GPUs in LLM processing tasks. As the demands of LLM research continue to grow, Groq LPUs are poised to become a leading choice for AI researchers and practitioners seeking increased computational efficiency.
# ----------------------------------------
#
# [Editor]: **Critique and Optimized Version**
# =====================================
#
# The provided text is well-structured and effectively conveys the advantages of Groq LPUs for Large Language Models (LLMs). However, there are some areas that can be improved for better clarity, concision, and professional delivery.
#
# **Optimized Version**
# --------------------
#
# ### **Introduction**
#
# The rapid advancement of Large Language Models (LLMs) has created a need for more efficient computing hardware. While General-Purpose Graphics Processing Units (GPUs) have been widely used in AI research, custom-designed hardware like Groq Linear-Processing-Units (LPUs) offer a promising alternative. This summary will explore the architecture and benefits of Groq LPUs for LLMs, focusing on their ability to provide higher throughput compared to standard GPUs.
#
# ### **Groq LPU Architecture**
#
# Groq LPUs are optimized for Linear Algebra and Neural Network computations, featuring a unique architecture that enables efficient matrix operations. Key differences between Groq LPUs and standard GPUs include:
#
# *   **Simplified Parallel Processing**: Groq LPUs employ a single Instruction Multiple Data (SIMD) execution paradigm, minimizing overhead and maximizing data throughput.
# *   **High-Density On-Chip Fabric**: The on-chip communication fabric facilitates rapid data exchange between processing units, reducing latency and improving performance.
# *   **Specialized Matrix-Vector Units (SMMUs)**: Groq LPUs feature SMMUs highly optimized for linear algebra operations, using a unique instruction format for efficient processing of sparse and dense matrices.
#
# ### **Benefits for Large Language Models (LLMs)**
#
# The tailored architecture of Groq LPUs provides significant benefits for LLMs:
#
# *   **Increased Throughput**: The combination of high-density on-chip fabric, SIMD execution, and SMMUs enables Groq LPUs to achieve higher matrix operation speeds, resulting in increased throughput for LLM computations.
# *   **Improved Power Efficiency**: Groq LPUs are designed to minimize power consumption while maintaining performance, crucial for LLM training with massive datasets and lengthy processing times.
# *   **Reduced Latency**: The streamlined architecture and on-chip fabric reduce latency for matrix operations, essential for real-time LLM applications.
#
# ### **Comparison with Standard GPUs**
#
# While standard GPUs excel at general-purpose computation, they have limitations when it comes to LLMs:
#
# *   **GPU Bottleneck**: Traditional parallel computing architectures used in GPUs introduce bottlenecks during LLM computations.
# *   **Memory Bandwidth Limitations**: GPUs' external memory access patterns can lead to limited memory bandwidth, negatively impacting performance.
# *   **Instruction-Level Overhead**: GPUs incur additional overhead due to serial execution of certain instructions, slowing down LLM computations.
#
# ### **Conclusion**
#
# Groq LPUs offer a superior architecture for LLM computations, providing higher throughput, improved power efficiency, and reduced latency. By leveraging a custom-designed paradigm, optimized matrix-vector units, and a high-density on-chip fabric, Groq LPUs outperform standard GPUs in LLM processing tasks. As LLM research continues to grow, Groq LPUs are poised to become a leading choice for AI researchers and practitioners seeking increased computational efficiency.
#
# **Changes Made**
# ----------------
#
# 1.  **Simplified Introduction**: The introduction has been rephrased for better clarity and concision.
# 2.  **Reorganized Sections**: The sections have been reorganized to improve the flow of information and reduce repetition.
# 3.  **Removed Redundant Information**: Redundant information has been removed to make the text more concise.
# 4.  **Improved Sentence Structure**: Sentence structures have been improved for better readability and clarity.
# 5.  **Added Transitions**: Transitions have been added between sections to enhance the overall flow of the text.
# 6.  **Minor Edits**: Minor edits have been made to improve grammar, punctuation, and formatting.
#
# These changes enhance the overall quality of the text, making it more suitable for professional delivery and academic purposes.
# ----------------------------------------
#
# [Researcher]: **Additional Improvements**
# -------------------------
#
# ### **Minor Edits**
#
# The provided optimized version shows significant improvements in clarity and concision. However, minor edits can further enhance the text:
#
# *   **Consistent Bullet Points**: Bullet points in the "Benefits for Large Language Models (LLMs)" and "Comparison with Standard GPUs" sections should be consistent in style and formatting.
# *   **Standard Grammar and Punctuation**: Minor grammar and punctuation errors should be corrected throughout the text.
# *   **Uniform Section Headings**: Section headings should have consistent formatting and styling.
#
# ### **Optimized Graphics**
#
# Considering the technical nature of the content, incorporating illustrations or diagrams to explain complex concepts can be highly beneficial:
#
# *   **Simplified Architecture Diagram**: A simplified diagram illustrating the differences between Groq LPUs and standard GPUs can help readers visualize the advantages of Groq LPUs.
# *   **Matrix Operation Visualization**: A visualization of matrix operations, highlighting how Groq LPUs' specialized Matrix-Vector Units (SMMUs) enable efficient computations, can improve reader understanding.
#
# ### **Technical Details**
#
# Incorporating technical details can further enhance the text, providing a more comprehensive understanding of Groq LPUs:
#
# *   **Quantum Computing Integration**: Discussing the potential of integrating quantum computing with Groq LPUs for LLMs can provide a unique perspective and demonstrate the cutting-edge nature of this technology.
# *   **Memory Hierarchy**: Explaining the memory hierarchy of Groq LPUs, including the benefits of on-chip fabric, can provide readers with a deeper understanding of the architecture.
#
# By incorporating these minor edits, illustrations, and technical details, the text can be further optimized to provide an in-depth and engaging explanation of Groq LPUs for Large Language Models (LLMs).
# ----------------------------------------

# %%
# ============================================================
#                    CELL 5 - EXTENSION TASKS
# ============================================================
# This cell extends the basic 2-agent system from Cell 4
# with 2 additional features:
#
# EXTENSION 1: Tool-Wielding Agent
#   - Added a real-world stock price fetcher tool (Python function)
#   - Attached it to the Researcher agent
#   - Task forces Researcher to CALL the tool to get live data
#   - Groq's function-calling capability handles this natively
#
# EXTENSION 2: UserProxy (Human-in-the-Loop)
#   - Added a UserProxyAgent as the 3rd participant
#   - After every Researcher + Editor round, conversation PAUSES
#   - YOU type feedback or approval in the input box
#   - Type "TERMINATE" to end the session cleanly
#
# AGENT FLOW:
#   Researcher (tool call) → Editor (critique) → UserProxy (you)
#   → repeats until TERMINATE or max 6 messages
# ============================================================

import os
from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_ext.models.openai import OpenAIChatCompletionClient

# ============================================================
# EXTENSION 1 — TOOL DEFINITION
# A real-world stock price fetcher using Yahoo Finance
# No API key needed — uses public endpoint
# The Researcher agent will CALL this function automatically
# when asked about stock prices
# ============================================================
def get_stock_price(ticker: str) -> str:
    """Fetches the latest stock price for a given ticker symbol."""
    try:
        import urllib.request
        import json
        # Yahoo Finance public API — no authentication needed
        url = f"https://query1.finance.yahoo.com/v8/finance/chart/{ticker}?interval=1d&range=1d"
        req = urllib.request.Request(url, headers={"User-Agent": "Mozilla/5.0"})
        with urllib.request.urlopen(req) as response:
            data = json.loads(response.read())
            price = data["chart"]["result"][0]["meta"]["regularMarketPrice"]
            currency = data["chart"]["result"][0]["meta"]["currency"]
            return f"{ticker} current price: {price} {currency}"
    except Exception as e:
        return f"Error fetching stock price: {str(e)}"


# ============================================================
# MAIN ASYNC FUNCTION — runs the full multi-agent pipeline
# ============================================================
async def run_team():

    # --------------------------------------------------------
    # Fetch Groq API key set securely in Cell 2
    # --------------------------------------------------------
    groq_key = os.environ.get("GROQ_API_KEY", "")

    # --------------------------------------------------------
    # RESEARCHER MODEL — faster, lightweight Groq model
    # Used for research + tool calling
    # --------------------------------------------------------
    researcher_model = OpenAIChatCompletionClient(
        model="llama-3.1-8b-instant",
        base_url="https://api.groq.com/openai/v1",
        api_key=groq_key,
        model_info={
            "vision": False,
            "function_calling": True,   # needed for tool calling
            "json_output": True,
            "structured_output": True,
            "family": "unknown"
        }
    )

    # --------------------------------------------------------
    # EDITOR MODEL — larger, more capable Groq model
    # Used for critique and professional refinement
    # --------------------------------------------------------
    editor_model = OpenAIChatCompletionClient(
        model="llama-3.3-70b-versatile",
        base_url="https://api.groq.com/openai/v1",
        api_key=groq_key,
        model_info={
            "vision": False,
            "function_calling": True,
            "json_output": True,
            "structured_output": True,
            "family": "unknown"
        }
    )

    # --------------------------------------------------------
    # EXTENSION 1 — RESEARCHER AGENT WITH TOOL
    # tools=[get_stock_price] attaches the real-world fetcher
    # System message explicitly instructs it to USE the tool
    # --------------------------------------------------------
    researcher = AssistantAgent(
        name="Researcher",
        model_client=researcher_model,
        tools=[get_stock_price],  # <-- tool attached here
        system_message="""You are an expert researcher with access to real-world tools.
        When asked about stock prices, you MUST call the get_stock_price tool first.
        Then provide a detailed analysis in clear Markdown format."""
    )

    # --------------------------------------------------------
    # EDITOR AGENT — no tool needed
    # Reviews researcher output and asks UserProxy for approval
    # --------------------------------------------------------
    editor = AssistantAgent(
        name="Editor",
        model_client=editor_model,
        system_message="""You are a strict editor.
        Review the researcher's findings and optimize for professional delivery.
        After your review, ask the UserProxy for approval before finishing."""
    )

    # --------------------------------------------------------
    # EXTENSION 2 — USER PROXY AGENT (Human-in-the-Loop)
    # input_func=input means it ALWAYS pauses for your response
    # You can type feedback or type TERMINATE to stop
    # --------------------------------------------------------
    user_proxy = UserProxyAgent(
        name="UserProxy",
        input_func=input  # pauses and waits for YOUR input every turn
    )

    # --------------------------------------------------------
    # TEAM SETUP — RoundRobin means agents go in fixed order:
    # Researcher → Editor → UserProxy → repeat
    # Stops at 6 messages OR when you type TERMINATE
    # --------------------------------------------------------
    team = RoundRobinGroupChat(
        participants=[researcher, editor, user_proxy],
        termination_condition=MaxMessageTermination(max_messages=6)
    )

    # --------------------------------------------------------
    # SESSION START — instructions printed for the user
    # --------------------------------------------------------
    print("=" * 55)
    print("   EXTENSION TASK — Multi-Agent Session Started")
    print("=" * 55)
    print("AGENT ORDER: Researcher → Editor → UserProxy (You)")
    print("-" * 55)
    print("💡 When UserProxy turn arrives:")
    print("   → Type your feedback and press Enter to continue")
    print("   → Type TERMINATE and press Enter to end session")
    print("=" * 55 + "\n")

    # --------------------------------------------------------
    # TASK — forces Researcher to call get_stock_price tool
    # This is the real-world data trigger for Extension 1
    # --------------------------------------------------------
    async for message in team.run_stream(
        task="Find the current stock price of Apple (AAPL) and provide a brief analysis of what it means for investors."
    ):
        # Skip the final TaskResult object — only print agent messages
        if hasattr(message, "source"):
            print(f"\n\033[1m[{message.source}]\033[0m: {message.content}")
            print("-" * 40)

# ============================================================
# RUN — executes the async function inside Google Colab
# ============================================================
await run_team()
# Out:
# =======================================================
#    EXTENSION TASK — Multi-Agent Session Started
# =======================================================
# AGENT ORDER: Researcher → Editor → UserProxy (You)
# -------------------------------------------------------
# 💡 When UserProxy turn arrives:
#    → Type your feedback and press Enter to continue
#    → Type TERMINATE and press Enter to end session
# =======================================================
#
#
# [user]: Find the current stock price of Apple (AAPL) and provide a brief analysis of what it means for investors.
# ----------------------------------------
#
# [Researcher]: [FunctionCall(id='wsh3gtksg', arguments='{"ticker":"AAPL"}', name='get_stock_price')]
# ----------------------------------------
#
# [Researcher]: [FunctionExecutionResult(content='AAPL current price: 298.01 USD', name='get_stock_price', call_id='wsh3gtksg', is_error=False)]
# ----------------------------------------
#
# [Researcher]: AAPL current price: 298.01 USD
# ----------------------------------------
#
# [Editor]: **Review of Apple (AAPL) Stock Price**
#
# As of the latest update, the current stock price of Apple (AAPL) is $298.01 USD. This valuation may be seen as a significant indicator of the company's performance and market sentiment.
#
# **Brief Analysis:**
#
# The stock price of $298.01 USD may reflect investor confidence in Apple's ability to continue innovating and maintaining its market share in the technology sector. Factors contributing to this price may include:
#
# 1. **Financial Performance:** Apple's revenue growth, profit margins, and earnings per share (EPS) may be influencing investor decisions.
# 2. **Product Lineup and Innovation:** The success of Apple's iPhone, Mac, and services segments, as well as the company's investments in emerging technologies, may be driving investor optimism.
# 3. **Market Trends:** Broader market trends, including the overall performance of the technology sector and global economic conditions, may also be impacting Apple's stock price.
#
# **Implications for Investors:**
#
# For investors, a stock price of $298.01 USD may indicate a potential buying opportunity, depending on their individual investment strategies and risk tolerance. It is essential to consider various factors, including Apple's financials, industry trends, and overall market conditions, before making any investment decisions.
#
# **Request for Approval:**
#
# Before finalizing this analysis, I request approval from the UserProxy to ensure that the information provided meets the required standards and is suitable for dissemination. Please confirm approval to proceed.
# ----------------------------------------
#
# [UserProxy]:
# ----------------------------------------
# Enter your response: Make the analysis simpler so a beginner investor can understand it
#
# [UserProxy]: Make the analysis simpler so a beginner investor can understand it
# ----------------------------------------
#
# [Researcher]: **Review of Apple (AAPL) Stock Price**
#
# As of the latest update, the current stock price of Apple (AAPL) is $298.01 USD.
#
# **What Does This Mean?**
#
# The stock price of $298.01 USD shows how much people are willing to pay for a single share of Apple stock. It's like the price of a toy - if many people want it and are willing to pay a lot, the price goes up.
#
# **Why is Apple's Stock Price Important?**
#
# A high stock price like Apple's (around $298.01 USD) can be a good sign for investors. It might mean that Apple is doing well and has a strong future. However, it's essential to remember that the stock market can be unpredictable, and prices can change quickly.
#
# **What Should Beginner Investors Do?**
#
# If you're new to investing, it's essential to do your research and understand the basics of investing in the stock market. You can start by learning about:
#
# 1. **What Apple does**: Apple makes iPhones, Macs, and other tech products.
# 2. **How the stock market works**: It's a place where people buy and sell shares (like tiny pieces of companies).
# 3. **Risk and reward**: Investing always involves some risk, but it can also be a way to grow your money over time.
#
# Remember, investing is a long-term game. It's essential to be patient, do your research, and consider your financial goals before making any investment decisions.
# ----------------------------------------
#
# [Editor]: **Edited Review of Apple (AAPL) Stock Price**
#
# As of the latest update, the current stock price of Apple (AAPL) is $298.01 USD.
#
# **Understanding the Stock Price**
#
# The stock price of $298.01 USD represents the current market value of one share of Apple stock. Think of it like the price of a product - if many people want to buy it, the price tends to rise.
#
# **Why Apple's Stock Price Matters**
#
# A high stock price, like Apple's, can indicate that the company is performing well and has a promising future. However, it's essential to remember that the stock market can be unpredictable, and prices can fluctuate rapidly.
#
# **Tips for Beginner Investors**
#
# If you're new to investing, consider the following:
#
# 1. **Learn about Apple**: Understand the company's products and services, such as iPhones and Macs.
# 2. **Familiarize yourself with the stock market**: It's a platform where people buy and sell shares of companies.
# 3. **Recognize the balance between risk and reward**: Investing involves some level of risk, but it can also be a way to grow your wealth over time.
#
# Remember to approach investing with a long-term perspective, do your research, and align your investments with your financial goals.
#
# **Request for Approval:**
#
# I request approval from the UserProxy to finalize this edited review, ensuring that the information is clear, concise, and suitable for beginner investors. Please confirm approval to proceed.
# ----------------------------------------
