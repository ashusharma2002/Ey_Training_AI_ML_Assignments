# %%
#data load and inspect
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.rcParams['figure.dpi'] = 120
sns.set_theme(style='whitegrid')

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
url= "https://raw.githubusercontent.com/rajatg1989/MLOPS/main/taxis_data.xlsx"
df = pd.read_excel(url)

print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %%
print("Dataset Shape:")
print(df.shape)

print("\nFirst 5 Rows:")
display(df.head())

print("\nDataset Information:")
print(df.info())

# Section 2 — Clean & Prepare
print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows Before Cleaning:")
print(df.duplicated().sum())

df = df.drop_duplicates()

print("\nDuplicate Rows Removed")
print("New Shape:", df.shape)
# Out:
# Dataset Shape:
# (6433, 14)
#
# First 5 Rows:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df = df.dropna()

print("Null values removed")
print(df.shape)
# Out:
# Null values removed
# (6341, 14)

# %%
df['pickup'] = pd.to_datetime(df['pickup'])
df['dropoff'] = pd.to_datetime(df['dropoff'])

print("Date columns converted")
# Out:
# Date columns converted

# %%
df['trip_duration'] = (
    df['dropoff'] - df['pickup']
).dt.total_seconds() / 60

print("Trip duration column created")

display(df[['pickup', 'dropoff', 'trip_duration']].head())
# Out:
# Trip duration column created
#                pickup             dropoff  trip_duration
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24       6.250000
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00       7.083333
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25       7.400000
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51      25.866667
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14       9.533333

# %%
df['pickup_hour'] = df['pickup'].dt.hour

print("Pickup hour feature created")

display(df[['pickup', 'pickup_hour']].head())
# Out:
# Pickup hour feature created
#                pickup  pickup_hour
# 0 2019-03-23 20:21:09           20
# 1 2019-03-04 16:11:55           16
# 2 2019-03-27 17:53:01           17
# 3 2019-03-10 01:23:59            1
# 4 2019-03-30 13:27:42           13

# %%
df['pickup_hour'] = df['pickup'].dt.hour

print("Pickup hour feature created")

display(df[['pickup', 'pickup_hour']].head())
# Out:
# Pickup hour feature created
#                pickup  pickup_hour
# 0 2019-03-23 20:21:09           20
# 1 2019-03-04 16:11:55           16
# 2 2019-03-27 17:53:01           17
# 3 2019-03-10 01:23:59            1
# 4 2019-03-30 13:27:42           13

# %%
#Section 3 — Explore with Statistics
print("Maximum Fare:")
print(df['fare'].max())

print("\nAverage Distance:")
print(df['distance'].mean())

print("\nAverage Trip Duration:")
print(df['trip_duration'].mean())
# Out:
# Maximum Fare:
# 150.0
#
# Average Distance:
# 2.9977069862797663
#
# Average Trip Duration:
# 14.349182568469745

# %%
print("Payment Counts:")
print(df['payment'].value_counts())

print("\nAverage Fare by Payment:")
print(df.groupby('payment')['fare'].mean())
# Out:
# Payment Counts:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64
#
# Average Fare by Payment:
# payment
# cash           11.259053
# credit card    13.531098
# Name: fare, dtype: float64

# %%
summary = (
    df.groupby('payment')
    .agg(
        avg_fare=('fare', 'mean'),
        avg_tip=('tip', 'mean'),
        avg_distance=('distance', 'mean'),
        total_trips=('fare', 'count')
    )
)

print(summary)
# Out:
#               avg_fare  avg_tip  avg_distance  total_trips
# payment
# cash         11.259053  0.00000      2.461760         1795
# credit card  13.531098  2.75163      3.209327         4546

# %%
# Section 4 — Visualise
plt.figure(figsize=(8,5))

sns.histplot(
    df['fare'],
    bins=30,
    kde=True
)

plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='payment',
    data=df
)

plt.title("Payment Methods")
plt.xlabel("Payment Type")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='distance',
    y='fare',
    hue='payment',
    data=df
)

plt.title("Distance vs Fare")
plt.xlabel("Distance")
plt.ylabel("Fare")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='payment',
    y='fare',
    hue='payment',
    data=df,
    legend=False
)

plt.title("Fare by Payment Type")
plt.xlabel("Payment")
plt.ylabel("Fare")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.violinplot(
    data=df,
    x='payment',
    y='fare',
    hue='color',
    split=True
)

plt.title("Fare Distribution by Payment and Taxi Color")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    x='pickup_hour',
    data=df
)

plt.title("Trips by Pickup Hour")
plt.xlabel("Hour")
plt.ylabel("Number of Trips")

plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18,10))

fig.suptitle(
    "NYC Taxi Data Dashboard",
    fontsize=18,
    fontweight='bold'
)

# Panel 1
sns.histplot(
    df['fare'],
    bins=30,
    kde=True,
    ax=axes[0,0]
)

axes[0,0].set_title("Fare Distribution")


# Panel 2
sns.countplot(
    x='payment',
    data=df,
    ax=axes[0,1]
)

axes[0,1].set_title("Payment Methods")


# Panel 3
sns.scatterplot(
    x='distance',
    y='fare',
    hue='payment',
    data=df,
    ax=axes[0,2]
)

axes[0,2].set_title("Distance vs Fare")


# Panel 4
corr = df[
    [
        'passengers',
        'distance',
        'fare',
        'tip',
        'total'
    ]
].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    ax=axes[1,0]
)

axes[1,0].set_title("Correlation Heatmap")


# Panel 5
sns.countplot(
    x='pickup_hour',
    data=df,
    ax=axes[1,1]
)

axes[1,1].set_title("Trips by Pickup Hour")


# Panel 6
sns.boxplot(
    x='payment',
    y='fare',
    hue='payment',
    data=df,
    legend=False,
    ax=axes[1,2]
)

axes[1,2].set_title("Fare by Payment")


plt.tight_layout()

plt.savefig("taxi_dashboard.png")

plt.show()

# %%
# Section 5 — Key Insights
print("Key Insights")
print("Most taxi rides were paid using credit cards, making it the most preferred payment method.")

print("There is a positive relationship between distance and fare. As trip distance increases, the fare generally increases.")

print("Higher fare trips tend to generate higher tip amounts, indicating a positive correlation between fare and tip.")

print("The fare distribution is right-skewed, meaning most trips have moderate fares while a small number of trips have very high fares.")
# Out:
# Key Insights
# Most taxi rides were paid using credit cards, making it the most preferred payment method.
# There is a positive relationship between distance and fare. As trip distance increases, the fare generally increases.
# Higher fare trips tend to generate higher tip amounts, indicating a positive correlation between fare and tip.
# The fare distribution is right-skewed, meaning most trips have moderate fares while a small number of trips have very high fares.

# %%
#NARRATIVE CONCLUSION
print("\nNARRATIVE CONCLUSION")

print(""" This analysis of the NYC Taxi dataset provides valuable insights into passenger travel behavior, fare patterns, and payment preferences. The data shows that credit card payments are the most commonly used payment method among passengers.

The analysis also reveals a clear positive relationship between trip distance and fare amount, which is expected as longer journeys typically cost more. Similarly, passengers taking higher-fare trips tend to leave larger tips, indicating a connection between fare value and tipping behavior.

The visualizations highlight that most taxi rides fall within a moderate fare range, while only a small number of trips result in very high fares. Pickup activity varies across different hours of the day, suggesting fluctuations in passenger demand.

Overall, the dataset demonstrates how data analysis and visualization techniques can be used to understand transportation trends, customer behavior, and operational patterns in the taxi industry. These insights can help businesses make data-driven decisions to improve services and customer experience.""")
# Out:
# NARRATIVE CONCLUSION
#  This analysis of the NYC Taxi dataset provides valuable insights into passenger travel behavior, fare patterns, and payment preferences. The data shows that credit card payments are the most commonly used payment method among passengers.
#
# The analysis also reveals a clear positive relationship between trip distance and fare amount, which is expected as longer journeys typically cost more. Similarly, passengers taking higher-fare trips tend to leave larger tips, indicating a connection between fare value and tipping behavior.
#
# The visualizations highlight that most taxi rides fall within a moderate fare range, while only a small number of trips result in very high fares. Pickup activity varies across different hours of the day, suggesting fluctuations in passenger demand.
#
# ...
